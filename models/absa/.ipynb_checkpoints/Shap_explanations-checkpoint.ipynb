# %%
import os
import torch
import shap
import numpy as np
from transformers import DistilBertTokenizerFast, DistilBertForSequenceClassification

# Paths and model setup
MODEL_PATH = os.path.abspath(os.path.join(os.path.dirname("__file__"), '../../results/cadec-absa/cadec-absa-model'))
MODEL_NAME = "distilbert-base-uncased"
MAX_LENGTH = 256

device = torch.device('cpu')
model = DistilBertForSequenceClassification.from_pretrained(MODEL_PATH)
model.to(device)
model.eval()
tokenizer = DistilBertTokenizerFast.from_pretrained(MODEL_NAME)

def predict_proba(texts):
    if isinstance(texts, np.ndarray):
        texts = texts.tolist()
    if isinstance(texts, str):
        texts = [texts]
    if not isinstance(texts, list):
        texts = list(texts)
    texts = [str(t) for t in texts]
    inputs = tokenizer(texts, padding=True, truncation=True, max_length=MAX_LENGTH, return_tensors="pt")
    inputs = {k: v.to(device) for k, v in inputs.items()}
    with torch.no_grad():
        outputs = model(**inputs)
        probs = torch.nn.functional.softmax(outputs.logits, dim=-1).cpu().numpy()
    return probs

sample_texts = [
    "This medicine helped me a lot with my pain.",
    "I had severe side effects and had to stop taking it.",
    "No improvement after two weeks of use.",
    "Much better than my previous medication."
]

explainer = shap.Explainer(predict_proba, shap.maskers.Text(tokenizer))
shap_values = explainer(sample_texts)

# %%
shap.plots.text(shap_values[0])
# Out:
# <div align='center'>
# <script>
#     document._hover_eipobocoaffbtdhhsmto = '_tp_eipobocoaffbtdhhsmto_output_0';
#     document._zoom_eipobocoaffbtdhhsmto = undefined;
#     function _output_onclick_eipobocoaffbtdhhsmto(i) {
#         var next_id = undefined;
#
#         if (document._zoom_eipobocoaffbtdhhsmto !== undefined) {
#             document.getElementById(document._zoom_eipobocoaffbtdhhsmto+ '_zoom').style.display = 'none';
#
#             if (document._zoom_eipobocoaffbtdhhsmto === '_tp_eipobocoaffbtdhhsmto_output_' + i) {
#                 document.getElementById(document._zoom_eipobocoaffbtdhhsmto).style.display = 'block';
#                 document.getElementById(document._zoom_eipobocoaffbtdhhsmto+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_eipobocoaffbtdhhsmto).style.display = 'none';
#                 document.getElementById(document._zoom_eipobocoaffbtdhhsmto+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_eipobocoaffbtdhhsmto !== '_tp_eipobocoaffbtdhhsmto_output_' + i) {
#             next_id = '_tp_eipobocoaffbtdhhsmto_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_eipobocoaffbtdhhsmto = next_id;
#     }
#     function _output_onmouseover_eipobocoaffbtdhhsmto(i, el) {
#         if (document._zoom_eipobocoaffbtdhhsmto !== undefined) { return; }
#         if (document._hover_eipobocoaffbtdhhsmto !== undefined) {
#             document.getElementById(document._hover_eipobocoaffbtdhhsmto + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_eipobocoaffbtdhhsmto).style.display = 'none';
#         }
#         document.getElementById('_tp_eipobocoaffbtdhhsmto_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_eipobocoaffbtdhhsmto = '_tp_eipobocoaffbtdhhsmto_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(np.float64(255.0), np.float64(13.0), np.float64(87.0), np.float64(0.3536145771439889)); border-radius: 3px; padding: 0px" id="_tp_eipobocoaffbtdhhsmto_output_0_name"
#     onclick="_output_onclick_eipobocoaffbtdhhsmto(0)"
#     onmouseover="_output_onmouseover_eipobocoaffbtdhhsmto(0, this);">Output 0</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(255.0), np.float64(13.0), np.float64(87.0), np.float64(1.0)); border-radius: 3px; padding: 0px" id="_tp_eipobocoaffbtdhhsmto_output_1_name"
#     onclick="_output_onclick_eipobocoaffbtdhhsmto(1)"
#     onmouseover="_output_onmouseover_eipobocoaffbtdhhsmto(1, this);">Output 1</div><br><br><div id='_tp_eipobocoaffbtdhhsmto_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="50.00000248463793%" y1="33" x2="50.00000248463793%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="50.00000248463793%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="39.035275307190616%" y1="33" x2="39.035275307190616%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="39.035275307190616%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.4</text><line x1="28.070548129743305%" y1="33" x2="28.070548129743305%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="28.070548129743305%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="17.105820952295986%" y1="33" x2="17.105820952295986%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="17.105820952295986%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="60.96472966208524%" y1="33" x2="60.96472966208524%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="60.96472966208524%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.6</text><line x1="71.92945683953255%" y1="33" x2="71.92945683953255%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="71.92945683953255%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="82.89418401697988%" y1="33" x2="82.89418401697988%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="82.89418401697988%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="54.60389340224719%" y1="33" x2="54.60389340224719%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="54.60389340224719%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.541988</text><text x="54.60389340224719%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.541988</text><text x="54.60389340224719%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="23.70495543472921%" y1="33" x2="23.70495543472921%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="23.70495543472921%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.260185</text><text x="23.70495543472921%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.260185</text><text x="23.70495543472921%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">Output 0</tspan>(inputs)</text><rect x="6.525737403081367%" width="17.179218031647846%" y="40" height="18" style="fill:rgb(np.float64(255.0), np.float64(0.0), np.float64(81.0808360603179)); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="13.145774444906971%" x2="23.70495543472921%" y1="60" y2="60" id="_fb_sbziqoxccffkouquyidv_ind_2" style="stroke:rgb(np.float64(255.0), np.float64(0.0), np.float64(81.0808360603179));stroke-width:2; opacity: 0"/><text x="18.425364939818092%" y="71" font-size="12px" id="_fs_sbziqoxccffkouquyidv_ind_2" fill="rgb(np.float64(255.0), np.float64(0.0), np.float64(81.0808360603179))" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.096</text><svg x="13.145774 ...

# %%
shap.plots.text(shap_values[1])
# Out:
# <div align='center'>
# <script>
#     document._hover_rzvdajejwwrwbniujldg = '_tp_rzvdajejwwrwbniujldg_output_0';
#     document._zoom_rzvdajejwwrwbniujldg = undefined;
#     function _output_onclick_rzvdajejwwrwbniujldg(i) {
#         var next_id = undefined;
#
#         if (document._zoom_rzvdajejwwrwbniujldg !== undefined) {
#             document.getElementById(document._zoom_rzvdajejwwrwbniujldg+ '_zoom').style.display = 'none';
#
#             if (document._zoom_rzvdajejwwrwbniujldg === '_tp_rzvdajejwwrwbniujldg_output_' + i) {
#                 document.getElementById(document._zoom_rzvdajejwwrwbniujldg).style.display = 'block';
#                 document.getElementById(document._zoom_rzvdajejwwrwbniujldg+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_rzvdajejwwrwbniujldg).style.display = 'none';
#                 document.getElementById(document._zoom_rzvdajejwwrwbniujldg+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_rzvdajejwwrwbniujldg !== '_tp_rzvdajejwwrwbniujldg_output_' + i) {
#             next_id = '_tp_rzvdajejwwrwbniujldg_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_rzvdajejwwrwbniujldg = next_id;
#     }
#     function _output_onmouseover_rzvdajejwwrwbniujldg(i, el) {
#         if (document._zoom_rzvdajejwwrwbniujldg !== undefined) { return; }
#         if (document._hover_rzvdajejwwrwbniujldg !== undefined) {
#             document.getElementById(document._hover_rzvdajejwwrwbniujldg + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_rzvdajejwwrwbniujldg).style.display = 'none';
#         }
#         document.getElementById('_tp_rzvdajejwwrwbniujldg_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_rzvdajejwwrwbniujldg = '_tp_rzvdajejwwrwbniujldg_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(np.float64(255.0), np.float64(13.0), np.float64(87.0), np.float64(1.0)); border-radius: 3px; padding: 0px" id="_tp_rzvdajejwwrwbniujldg_output_0_name"
#     onclick="_output_onclick_rzvdajejwwrwbniujldg(0)"
#     onmouseover="_output_onmouseover_rzvdajejwwrwbniujldg(0, this);">Output 0</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(255.0), np.float64(13.0), np.float64(87.0), np.float64(0.030421865715983164)); border-radius: 3px; padding: 0px" id="_tp_rzvdajejwwrwbniujldg_output_1_name"
#     onclick="_output_onclick_rzvdajejwwrwbniujldg(1)"
#     onmouseover="_output_onmouseover_rzvdajejwwrwbniujldg(1, this);">Output 1</div><br><br><div id='_tp_rzvdajejwwrwbniujldg_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.99999992210884%" y1="33" x2="49.99999992210884%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.99999992210884%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="36.13258822194801%" y1="33" x2="36.13258822194801%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="36.13258822194801%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="22.265176521787183%" y1="33" x2="22.265176521787183%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="22.265176521787183%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="8.397764821626355%" y1="33" x2="8.397764821626355%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="8.397764821626355%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="63.86741162226967%" y1="33" x2="63.86741162226967%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="63.86741162226967%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="77.7348233224305%" y1="33" x2="77.7348233224305%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="77.7348233224305%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="91.60223502259134%" y1="33" x2="91.60223502259134%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="91.60223502259134%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="51.77877406377344%" y1="33" x2="51.77877406377344%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.77877406377344%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.525654</text><text x="51.77877406377344%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.525654</text><text x="51.77877406377344%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="82.5447893182357%" y1="33" x2="82.5447893182357%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="82.5447893182357%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.969371</text><text x="82.5447893182357%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.969371</text><text x="82.5447893182357%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">Output 0</tspan>(inputs)</text><rect x="39.796600344650535%" width="42.748188973585165%" y="40" height="18" style="fill:rgb(np.float64(255.0), np.float64(0.0), np.float64(81.0808360603179)); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="65.02730886265797%" x2="82.5447893182357%" y1="60" y2="60" id="_fb_emyddkudjuujljrsvysc_ind_5" style="stroke:rgb(np.float64(255.0), np.float64(0.0), np.float64(81.0808360603179));stroke-width:2; opacity: 0"/><text x="73.78604909044684%" y="71" font-size="12px" id="_fs_emyddkudjuujljrsvysc_ind_5" fill="rgb(np.float64(255.0), np.float64(0.0), np.float64(81.0808360603179))" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.253</text><svg x="65.02730886265797%" y="4 ...

# %%
shap.plots.text(shap_values[2])
# Out:
# <div align='center'>
# <script>
#     document._hover_awlcovqypoojsbqdkzgx = '_tp_awlcovqypoojsbqdkzgx_output_0';
#     document._zoom_awlcovqypoojsbqdkzgx = undefined;
#     function _output_onclick_awlcovqypoojsbqdkzgx(i) {
#         var next_id = undefined;
#
#         if (document._zoom_awlcovqypoojsbqdkzgx !== undefined) {
#             document.getElementById(document._zoom_awlcovqypoojsbqdkzgx+ '_zoom').style.display = 'none';
#
#             if (document._zoom_awlcovqypoojsbqdkzgx === '_tp_awlcovqypoojsbqdkzgx_output_' + i) {
#                 document.getElementById(document._zoom_awlcovqypoojsbqdkzgx).style.display = 'block';
#                 document.getElementById(document._zoom_awlcovqypoojsbqdkzgx+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_awlcovqypoojsbqdkzgx).style.display = 'none';
#                 document.getElementById(document._zoom_awlcovqypoojsbqdkzgx+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_awlcovqypoojsbqdkzgx !== '_tp_awlcovqypoojsbqdkzgx_output_' + i) {
#             next_id = '_tp_awlcovqypoojsbqdkzgx_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_awlcovqypoojsbqdkzgx = next_id;
#     }
#     function _output_onmouseover_awlcovqypoojsbqdkzgx(i, el) {
#         if (document._zoom_awlcovqypoojsbqdkzgx !== undefined) { return; }
#         if (document._hover_awlcovqypoojsbqdkzgx !== undefined) {
#             document.getElementById(document._hover_awlcovqypoojsbqdkzgx + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_awlcovqypoojsbqdkzgx).style.display = 'none';
#         }
#         document.getElementById('_tp_awlcovqypoojsbqdkzgx_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_awlcovqypoojsbqdkzgx = '_tp_awlcovqypoojsbqdkzgx_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(np.float64(255.0), np.float64(13.0), np.float64(87.0), np.float64(1.0)); border-radius: 3px; padding: 0px" id="_tp_awlcovqypoojsbqdkzgx_output_0_name"
#     onclick="_output_onclick_awlcovqypoojsbqdkzgx(0)"
#     onmouseover="_output_onmouseover_awlcovqypoojsbqdkzgx(0, this);">Output 0</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(255.0), np.float64(13.0), np.float64(87.0), np.float64(0.20384234501881549)); border-radius: 3px; padding: 0px" id="_tp_awlcovqypoojsbqdkzgx_output_1_name"
#     onclick="_output_onclick_awlcovqypoojsbqdkzgx(1)"
#     onmouseover="_output_onmouseover_awlcovqypoojsbqdkzgx(1, this);">Output 1</div><br><br><div id='_tp_awlcovqypoojsbqdkzgx_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.99999651734539%" y1="33" x2="49.99999651734539%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.99999651734539%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="35.412857331018856%" y1="33" x2="35.412857331018856%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="35.412857331018856%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="20.825718144692324%" y1="33" x2="20.825718144692324%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="20.825718144692324%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="64.58713570367192%" y1="33" x2="64.58713570367192%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="64.58713570367192%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="79.17427488999846%" y1="33" x2="79.17427488999846%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.17427488999846%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="53.07231609393137%" y1="33" x2="53.07231609393137%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="53.07231609393137%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.563186</text><text x="53.07231609393137%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.563186</text><text x="53.07231609393137%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="65.86351409217681%" y1="33" x2="65.86351409217681%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="65.86351409217681%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.82625</text><text x="65.86351409217681%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.82625</text><text x="65.86351409217681%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">Output 0</tspan>(inputs)</text><rect x="25.691178075797474%" width="40.17233601637934%" y="40" height="18" style="fill:rgb(np.float64(255.0), np.float64(0.0), np.float64(81.0808360603179)); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="53.784991788891666%" x2="65.86351409217681%" y1="60" y2="60" id="_fb_hpvbhmjjvqvfpvnzxyjo_ind_3" style="stroke:rgb(np.float64(255.0), np.float64(0.0), np.float64(81.0808360603179));stroke-width:2; opacity: 0"/><text x="59.82425294053424%" y="71" font-size="12px" id="_fs_hpvbhmjjvqvfpvnzxyjo_ind_3" fill="rgb(np.float64(255.0), np.float64(0.0), np.float64(81.0808360603179))" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.248</text><svg x="53.784991788891666%" y="40" height="20" width="12.078522303285148%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">after</text>  </svg></svg><line x1="43.285439100464636%" x2="53.784991788891666%" y1="60" y2="60" id="_fb_hpvbhmjjvqvfpvnzxyjo_ind_2" style="stroke:rgb(np.float64(255.0), np.float64(0.0), np.float64(81.0808360603179));stroke-width:2; opacity: 0"/><text x="48.53521544467815%" y="71" font-size="1 ...

# %%
shap.plots.text(shap_values[3])
# Out:
# <div align='center'>
# <script>
#     document._hover_hofipnawsuvqwsqlrtpj = '_tp_hofipnawsuvqwsqlrtpj_output_0';
#     document._zoom_hofipnawsuvqwsqlrtpj = undefined;
#     function _output_onclick_hofipnawsuvqwsqlrtpj(i) {
#         var next_id = undefined;
#
#         if (document._zoom_hofipnawsuvqwsqlrtpj !== undefined) {
#             document.getElementById(document._zoom_hofipnawsuvqwsqlrtpj+ '_zoom').style.display = 'none';
#
#             if (document._zoom_hofipnawsuvqwsqlrtpj === '_tp_hofipnawsuvqwsqlrtpj_output_' + i) {
#                 document.getElementById(document._zoom_hofipnawsuvqwsqlrtpj).style.display = 'block';
#                 document.getElementById(document._zoom_hofipnawsuvqwsqlrtpj+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_hofipnawsuvqwsqlrtpj).style.display = 'none';
#                 document.getElementById(document._zoom_hofipnawsuvqwsqlrtpj+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_hofipnawsuvqwsqlrtpj !== '_tp_hofipnawsuvqwsqlrtpj_output_' + i) {
#             next_id = '_tp_hofipnawsuvqwsqlrtpj_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_hofipnawsuvqwsqlrtpj = next_id;
#     }
#     function _output_onmouseover_hofipnawsuvqwsqlrtpj(i, el) {
#         if (document._zoom_hofipnawsuvqwsqlrtpj !== undefined) { return; }
#         if (document._hover_hofipnawsuvqwsqlrtpj !== undefined) {
#             document.getElementById(document._hover_hofipnawsuvqwsqlrtpj + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_hofipnawsuvqwsqlrtpj).style.display = 'none';
#         }
#         document.getElementById('_tp_hofipnawsuvqwsqlrtpj_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_hofipnawsuvqwsqlrtpj = '_tp_hofipnawsuvqwsqlrtpj_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(np.float64(255.0), np.float64(13.0), np.float64(87.0), np.float64(1.0)); border-radius: 3px; padding: 0px" id="_tp_hofipnawsuvqwsqlrtpj_output_0_name"
#     onclick="_output_onclick_hofipnawsuvqwsqlrtpj(0)"
#     onmouseover="_output_onmouseover_hofipnawsuvqwsqlrtpj(0, this);">Output 0</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(255.0), np.float64(13.0), np.float64(87.0), np.float64(0.014656367597544035)); border-radius: 3px; padding: 0px" id="_tp_hofipnawsuvqwsqlrtpj_output_1_name"
#     onclick="_output_onclick_hofipnawsuvqwsqlrtpj(1)"
#     onmouseover="_output_onmouseover_hofipnawsuvqwsqlrtpj(1, this);">Output 1</div><br><br><div id='_tp_hofipnawsuvqwsqlrtpj_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.99999969501162%" y1="33" x2="49.99999969501162%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.99999969501162%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="34.19392951562951%" y1="33" x2="34.19392951562951%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.19392951562951%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="18.38785933624742%" y1="33" x2="18.38785933624742%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="18.38785933624742%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="65.80606987439371%" y1="33" x2="65.80606987439371%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="65.80606987439371%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="81.6121400537758%" y1="33" x2="81.6121400537758%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="81.6121400537758%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="54.942755266750595%" y1="33" x2="54.942755266750595%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="54.942755266750595%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.562542</text><text x="54.942755266750595%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.562542</text><text x="54.942755266750595%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="88.22676195110117%" y1="33" x2="88.22676195110117%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="88.22676195110117%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.983697</text><text x="88.22676195110117%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.983697</text><text x="88.22676195110117%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">Output 0</tspan>(inputs)</text><rect x="47.90539144161705%" width="40.32137050948413%" y="40" height="18" style="fill:rgb(np.float64(255.0), np.float64(0.0), np.float64(81.0808360603179)); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="54.754953434292105%" x2="88.22676195110117%" y1="60" y2="60" id="_fb_vdjiylqlbgqilvousywu_ind_6" style="stroke:rgb(np.float64(255.0), np.float64(0.0), np.float64(81.0808360603179));stroke-width:2; opacity: 0"/><text x="71.49085769269664%" y="71" font-size="12px" id="_fs_vdjiylqlbgqilvousywu_ind_6" fill="rgb(np.float64(255.0), np.float64(0.0), np.float64(81.0808360603179))" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.424</text><svg x="54.754953434292105%" y="40" height="20" width="33.47180851680906%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">medication</text>  </svg></svg><line x1="52.18020779929958%" x2="54.754953434292105%" y1="60" y2="60" id="_fb_vdjiylqlbgqilvousywu_ind_4" style="stroke:rgb(np.float64(255.0), np.float64(0.0), np.float64(81.0808360603179));stroke-width:2; opacity: 0"/><text x="53.46758061679584%" y="71" font-size="12 ...
